# %%
import random
random.seed(2911)
import numpy as np
np.random.seed(2911)
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib import cm
import anndata as ad
# Out:
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata=ad.read('./new/hackathon_scfates.h5ad')
# Out:
# /data/mcri_brain/mcri_marian/env/conda/rapidai/lib/python3.10/site-packages/anndata/__init__.py:52: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
sc.tl.score_genes(adata,['NANOG','SOX2','POU5F1','ERBB2'],score_name='stem_score')
sc.pl.umap(adata,color=['stem_score'])
# Out:
# WARNING: genes are not in var_names and ignored: ['NANOG', 'POU5F1', 'ERBB2']
